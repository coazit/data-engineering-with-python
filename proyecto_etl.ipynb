# %%
##EXTRACCION, LIMPIEZA, TRANSFORMACIÓN Y CARGA

# %%
import pandas as pd
import datetime
from sqlalchemy import create_engine as ce

# %%
#Parametros de Acceso a BD Mysql
protocol = "mysql"
username = 'root'
password = '123456'
url = 'localhost'
port = 3306
db="etl_project"

# %%
# Conexion de Sql Alchemist para que use BD etl_project de Mysql
connection_string = f"{protocol}://{username}:{password}@{url}:{port}/{db}"

# %%
#mysql_engine 
mysqlengine = ce(connection_string)

# %%
## Pasar Data de CSV customer a Tabla customer de la bd etl_project de Mysql

# %%
df_customer = pd.read_csv("data/proyecto/customer", header=None, sep="|")

# %%
df_customer
# Out:
#            0         1          2          3          4  \
# 0          1   Richard  Hernandez  XXXXXXXXX  XXXXXXXXX
# 1          2      Mary    Barrett  XXXXXXXXX  XXXXXXXXX
# 2          3       Ann      Smith  XXXXXXXXX  XXXXXXXXX
# 3          4      Mary      Jones  XXXXXXXXX  XXXXXXXXX
# 4          5    Robert     Hudson  XXXXXXXXX  XXXXXXXXX
# ...      ...       ...        ...        ...        ...
# 12430  12431      Mary       Rios  XXXXXXXXX  XXXXXXXXX
# 12431  12432    Angela      Smith  XXXXXXXXX  XXXXXXXXX
# 12432  12433  Benjamin     Garcia  XXXXXXXXX  XXXXXXXXX
# 12433  12434      Mary      Mills  XXXXXXXXX  XXXXXXXXX
# 12434  12435     Laura     Horton  XXXXXXXXX  XXXXXXXXX
#
#                                 5            6   7      8
# 0              6303 Heather Plaza  Brownsville  TX  78521
# 1         9526 Noble Embers Ridge    Littleton  CO  80126
# 2          3422 Blue Pioneer Bend       Caguas  PR    725
# ...

# %%
df_customer.drop(df_customer.columns[[3,4,8]], axis=1, inplace=True)

# %%
df_customer.head()
# Out:
#    0        1          2                        5            6   7
# 0  1  Richard  Hernandez       6303 Heather Plaza  Brownsville  TX
# 1  2     Mary    Barrett  9526 Noble Embers Ridge    Littleton  CO
# 2  3      Ann      Smith   3422 Blue Pioneer Bend       Caguas  PR
# 3  4     Mary      Jones       8324 Little Common   San Marcos  CA
# 4  5   Robert     Hudson   10 Crystal River Mall        Caguas  PR

# %%
df_customer.columns= ['customer_id', 'customer_name', 'customer_last_name','customer_address', 'customer_department', 'customer_country',]

# %%
df_customer.head()
# Out:
#    customer_id customer_name customer_last_name         customer_address  \
# 0            1       Richard          Hernandez       6303 Heather Plaza
# 1            2          Mary            Barrett  9526 Noble Embers Ridge
# 2            3           Ann              Smith   3422 Blue Pioneer Bend
# 3            4          Mary              Jones       8324 Little Common
# 4            5        Robert             Hudson   10 Crystal River Mall
#
#   customer_department customer_country
# 0         Brownsville               TX
# 1           Littleton               CO
# 2              Caguas               PR
# 3          San Marcos               CA
# 4              Caguas               PR

# %%
##Pasar data a tabla customer de Mysql
df_customer.to_sql(name="customer", con=mysqlengine, if_exists='append', index=False)
# Out:
# 12435

# %%
## Pasar Data de CSV categories a Tabla categories de la bd etl_project de Mysql

# %%
df_order_items = pd.read_csv("data/proyecto/order_items", header=None, sep="|" )

# %%
df_order_items
# Out:
#              0      1     2  3        4        5
# 0            1      1   957  1   299.98   299.98
# 1            2      2  1073  1   199.99   199.99
# 2            3      2   502  5   250.00    50.00
# 3            4      2   403  1   129.99   129.99
# 4            5      4   897  2    49.98    24.99
# ...        ...    ...   ... ..      ...      ...
# 172193  172194  68881   403  1   129.99   129.99
# 172194  172195  68882   365  1    59.99    59.99
# 172195  172196  68882   502  1    50.00    50.00
# 172196  172197  68883   208  1  1999.99  1999.99
# 172197  172198  68883   502  3   150.00    50.00
#
# [172198 rows x 6 columns]

# %%
df_order_items.columns= ['order_item_id', 'order_item_order_id', 'order_item_product_id','order_item_quantity', 'order_item_subtotal', 'order_item_productprice']

# %%
df_order_items.head()
# Out:
#    order_item_id  order_item_order_id  order_item_product_id  \
# 0              1                    1                    957
# 1              2                    2                   1073
# 2              3                    2                    502
# 3              4                    2                    403
# 4              5                    4                    897
#
#    order_item_quantity  order_item_subtotal  order_item_productprice
# 0                    1               299.98                   299.98
# 1                    1               199.99                   199.99
# 2                    5               250.00                    50.00
# 3                    1               129.99                   129.99
# 4                    2                49.98                    24.99

# %%
##Pasar data a tabla order_items de Mysql
df_order_items.to_sql(name="order_items", con=mysqlengine, if_exists='append', index=False)
# Out:
# 172198

# %%
## Pasar Data de CSV orders a Tabla orders de la bd etl_project de Mysql

# %%
df_orders = pd.read_csv("data/proyecto/orders", header=None, sep="|")

# %%
df_orders
# Out:
#            0                      1      2                3
# 0          1  2013-07-25 00:00:00.0  11599           CLOSED
# 1          2  2013-07-25 00:00:00.0    256  PENDING_PAYMENT
# 2          3  2013-07-25 00:00:00.0  12111         COMPLETE
# 3          4  2013-07-25 00:00:00.0   8827           CLOSED
# 4          5  2013-07-25 00:00:00.0  11318         COMPLETE
# ...      ...                    ...    ...              ...
# 68878  68879  2014-07-09 00:00:00.0    778         COMPLETE
# 68879  68880  2014-07-13 00:00:00.0   1117         COMPLETE
# 68880  68881  2014-07-19 00:00:00.0   2518  PENDING_PAYMENT
# 68881  68882  2014-07-22 00:00:00.0  10000          ON_HOLD
# 68882  68883  2014-07-23 00:00:00.0   5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
df_orders.columns= ['order_id', 'order_date', 'order_customer_id','order_status']

# %%
df_orders.head()
# Out:
#    order_id             order_date  order_customer_id     order_status
# 0         1  2013-07-25 00:00:00.0              11599           CLOSED
# 1         2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2         3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3         4  2013-07-25 00:00:00.0               8827           CLOSED
# 4         5  2013-07-25 00:00:00.0              11318         COMPLETE

# %%
##Pasar data a tabla orders de Mysql
df_orders.to_sql(name="orders", con=mysqlengine, if_exists='append', index=False)
# Out:
# 68883

# %%
## Pasar Data de CSV categories a Tabla orders de la bd etl_project de Mysql

# %%
df_categories = pd.read_csv("data/proyecto/categories", header=None, sep="|" )

# %%
df_categories
# Out:
#      0  1                     2
# 0    1  2              Football
# 1    2  2                Soccer
# 2    3  2   Baseball & Softball
# 3    4  2            Basketball
# 4    5  2              Lacrosse
# 5    6  2      Tennis & Racquet
# 6    7  2                Hockey
# 7    8  2           More Sports
# 8    9  3      Cardio Equipment
# 9   10  3     Strength Training
# 10  11  3   Fitness Accessories
# 11  12  3          Boxing & MMA
# 12  13  3           Electronics
# 13  14  3        Yoga & Pilates
# 14  15  3     Training by Sport
# 15  16  3       As Seen on  TV!
# 16  17  4                Cleats
# 17  18  4        Men's Footwear
# 18  19  4      Women's Footwear
# 19  20  4        Kids' Footwear
# 20  21  4        Featured Shops
# 21  22  4           Accessories
# 22  23  5         Men's Apparel
# 23  24  5       Women's Apparel
# 24  25  5         Boys' Apparel
# 25  26  5        Girls' Apparel
# 26  27  5           Accessories
# 27  28  5            Top Brands
# ...

# %%
df_categories.columns = ['category_id','category_departament_id','category_name']

# %%
df_categories.head()
# Out:
#    category_id  category_departament_id        category_name
# 0            1                        2             Football
# 1            2                        2               Soccer
# 2            3                        2  Baseball & Softball
# 3            4                        2           Basketball
# 4            5                        2             Lacrosse

# %%
##Pasar data a tabla orders de Mysql
df_categories.to_sql(name="categories", con=mysqlengine, if_exists='append', index=False)
# Out:
# 58

# %%
## lectura de CSV products

# %%
df_products = pd.read_csv("data/proyecto/products", header=None, sep="|")

# %%
df_products
# Out:
#          0   1                                              2   3       4  \
# 0        1   2  Quest Q64 10 FT. x 10 FT. Slant Leg Instant U NaN   59.98
# 1        2   2  Under Armour Men's Highlight MC Football Clea NaN  129.99
# 2        3   2  Under Armour Men's Renegade D Mid Football Cl NaN   89.99
# 3        4   2  Under Armour Men's Renegade D Mid Football Cl NaN   89.99
# 4        5   2  Riddell Youth Revolution Speed Custom Footbal NaN  199.99
# ...    ...  ..                                            ...  ..     ...
# 1340  1341  59  Nike Women's Cleveland Browns Johnny Football NaN   34.00
# 1341  1342  59  Nike Men's St. Louis Rams Michael Sam #96 Nam NaN   32.00
# 1342  1343  59  Nike Men's Home Game Jersey St. Louis Rams Mi NaN  100.00
# 1343  1344  59  Nike Men's Home Game Jersey St. Louis Rams Aa NaN  100.00
# 1344  1345  59  Nike Men's Home Game Jersey St. Louis Rams Gr NaN  100.00
#
#                                                       5
# ...

# %%
#Eliminamos tablas con valores nulos
df_products.drop(df_products.columns[[3]], axis=1, inplace=True)

# %%
df_products.head()
# Out:
#    0  1                                              2       4  \
# 0  1  2  Quest Q64 10 FT. x 10 FT. Slant Leg Instant U   59.98
# 1  2  2  Under Armour Men's Highlight MC Football Clea  129.99
# 2  3  2  Under Armour Men's Renegade D Mid Football Cl   89.99
# 3  4  2  Under Armour Men's Renegade D Mid Football Cl   89.99
# 4  5  2  Riddell Youth Revolution Speed Custom Footbal  199.99
#
#                                                    5
# 0  http://images.acmesports.sports/Quest+Q64+10+F...
# 1  http://images.acmesports.sports/Under+Armour+M...
# 2  http://images.acmesports.sports/Under+Armour+M...
# 3  http://images.acmesports.sports/Under+Armour+M...
# 4  http://images.acmesports.sports/Riddell+Youth+...

# %%
df_products.columns = ['product_id','product_category_id','product_name','product_price','product_image']

# %%
df_products.head()
# Out:
#    product_id  product_category_id  \
# 0           1                    2
# 1           2                    2
# 2           3                    2
# 3           4                    2
# 4           5                    2
#
#                                     product_name  product_price  \
# 0  Quest Q64 10 FT. x 10 FT. Slant Leg Instant U          59.98
# 1  Under Armour Men's Highlight MC Football Clea         129.99
# 2  Under Armour Men's Renegade D Mid Football Cl          89.99
# 3  Under Armour Men's Renegade D Mid Football Cl          89.99
# 4  Riddell Youth Revolution Speed Custom Footbal         199.99
#
#                                        product_image
# 0  http://images.acmesports.sports/Quest+Q64+10+F...
# 1  http://images.acmesports.sports/Under+Armour+M...
# 2  http://images.acmesports.sports/Under+Armour+M...
# 3  http://images.acmesports.sports/Under+Armour+M...
# 4  http://images.acmesports.sports/Riddell+Youth+...

# %%
## lectura de CSV departments

# %%
df_departments = pd.read_csv("data/proyecto/departments", header=None, sep="|")

# %%
df_departments
# Out:
#    0         1
# 0  2   Fitness
# 1  3  Footwear
# 2  4   Apparel
# 3  5      Golf
# 4  6  Outdoors
# 5  7  Fan Shop

# %%
df_departments.head()
# Out:
#    0         1
# 0  2   Fitness
# 1  3  Footwear
# 2  4   Apparel
# 3  5      Golf
# 4  6  Outdoors

# %%
df_departments.columns = ['department_id','department_name']

# %%
df_departments.head()
# Out:
#    department_id department_name
# 0              2         Fitness
# 1              3        Footwear
# 2              4         Apparel
# 3              5            Golf
# 4              6        Outdoors

# %%
##Cargar Datos a tabla de hecho data_comercial para anslisis de kpis

# %%
##Merge de Order y order_items

# %%
df_data_orders = df_orders.merge(df_order_items, left_on= ['order_id'], right_on = ['order_item_id'], how='left')

# %%
df_data_orders
# Out:
#        order_id             order_date  order_customer_id     order_status  \
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
#        order_item_id  order_item_order_id  order_item_product_id  \
# ...

# %%
##Merge de data order con customer

# %%
df_data_customer_order = df_data_orders.merge(df_customer, left_on= ['order_customer_id'], right_on = ['customer_id'], how='left')

# %%
df_data_customer_order
# Out:
#        order_id             order_date  order_customer_id     order_status  \
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
#        order_item_id  order_item_order_id  order_item_product_id  \
# ...

# %%
##Merge de data customer_order con productos adquiridos.

# %%
df_data_comercial = df_data_customer_order.merge(df_products, left_on= ['order_item_product_id'], right_on = ['product_id'], how='left')

# %%
df_data_comercial
# Out:
#        order_id             order_date  order_customer_id     order_status  \
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
#        order_item_id  order_item_order_id  order_item_product_id  \
# ...

# %%
##Cargar la data procesada a un tabla data_comercial de la Base de Datos etl_project de POSTGRES

# %%
#Parametros de Acceso a BD Mysql
protocol = "postgresql"
username = 'postgres'
password = '123456'
url = 'localhost'
port = 5432
db="etl_project"

# %%
# Conexion de Sql Alchemist para que use BD etl_project de Mysql
connection_string_postgres = f"{protocol}://{username}:{password}@{url}:{port}/{db}"

# %%
#mysql_engine 
postgresengine = ce(connection_string_postgres)

# %%
##Pasar data a tabla orders de Mysql
df_data_comercial.to_sql(name="data_comercial", con=postgresengine, if_exists='append', index=False)
# Out:
# 883

# %%
#Validamos la información cargada
df_data_comercial_db = pd.read_sql_query("SELECT * FROM data_comercial", con=postgresengine).head()

# %%
df_data_comercial_db
# Out:
#    order_id             order_date  order_customer_id     order_status  \
# 0         1  2013-07-25 00:00:00.0              11599           CLOSED
# 1         2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2         3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3         4  2013-07-25 00:00:00.0               8827           CLOSED
# 4         5  2013-07-25 00:00:00.0              11318         COMPLETE
#
#    order_item_id  order_item_order_id  order_item_product_id  \
# 0              1                    1                    957
# 1              2                    2                   1073
# 2              3                    2                    502
# 3              4                    2                    403
# 4              5                    4                    897
#
#    order_item_quantity  order_item_subtotal  order_item_productprice  ...  \
# 0                    1               299.98                   299.98  ...
# ...

# %%
df_data_comercial_db.columns
# Out:
# Index(['order_id', 'order_date', 'order_customer_id', 'order_status',
#        'order_item_id', 'order_item_order_id', 'order_item_product_id',
#        'order_item_quantity', 'order_item_subtotal', 'order_item_productprice',
#        'customer_id', 'customer_name', 'customer_last_name',
#        'customer_address', 'customer_department', 'customer_country',
#        'product_id', 'product_category_id', 'product_name', 'product_price',
#        'product_image'],
#       dtype='object')
